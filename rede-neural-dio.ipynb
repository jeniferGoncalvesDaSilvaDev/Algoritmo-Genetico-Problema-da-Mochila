# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/Algoritmo-Genetico-Problema-da-Mochila/blob/main/rede-neural-dio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#machine learning- aula dio
from matplotlib import pyplot as plt
#cria a regreassao
from sklearn.datasets import make_regression
#gerando 200 amostras
x,y = make_regression(n_samples=200, n_features=1, noise=30)

# %%
plt.scatter(x,y)
plt.show()

# %%
#implememtando uma rede neural
#implementando o minist, ou seja, numeros escritos a mão
import numpy as np
#framework de programaçao para deep learning-pytorch
import torch
#importar funçoes para a rede neural
import torch.nn.functional as F
#visao computacional
import torchvision
#tempo de execuçao e resposta da rede
from time import time
from torchvision import datasets, transforms
from torch import nn,optim

# %%
transform = transforms.ToTensor() #definindo a conversaéo de imagem para tensor



trainset = datasets.MNIST("./MNIST_data/", download=True, train=True, transform=transform) # Carrega a parte de treino do dataset
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True) # Cria um buffer para pegar os dados por partes
valset = datasets.MNIST("./MNIST_data/", download=True, train=False, transform=transform) # Carrega a parte de validacao do dataset
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True) # Cria um buffer para pegar os dados por partes

# %%
#carrega as imagens


dataiter = iter(trainloader)
data = next(dataiter)
print(len(data))
plt.imshow(data[0], cmap='gray_r');
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-8a9fe527469b> in <cell line: 7>()
#       5 data = next(dataiter)
#       6 print(len(data))
# ----> 7 plt.imshow(data[0], cmap='gray_r');
#       8
#       9
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
#para verificar as dimensoes em cada imagem
print(data[0].shape)
torch.Size([1,28,28])
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([1, 28, 28])

# %%
class Modelo(nn.Module) : # trabalha com 128 neuronio e se ligam a 64 neuronios
  def __init__(self):
    super(Modelo, self). __init__()
    self.linear1 = nn.Linear(28*28, 128) # camada de entrada, 784 neurénios que se ligam a 128
    self.linear2 = nn.Linear(128, 64) # camada interna 1, 128 nqurénios que se ligam a 64
    self.linear3 = nn.Linear(64, 10) # camada interna 2, 64 neurénios que se ligam a 1¢
# para a camada de saida nao e necessério definir nada pois s6 precisamos pegar o output da camada interna 2





  def forward(self,x):
    X = F.relu(self.linear1(X)) # funcado de ativacdo da camada de entrada para a camada interna 1
    X = F.relu(self.linear2(x)) # funcao de ativacaéo da camada interna 1 para a camada interna 2
    X = self.linear3(X) # funcdo de ativacao da camada interna 2 para a camada de saida, nesse caso f(x) = x
    return F.log_softmax(X, dim=1) # dados utilizados para calcular a perda|_ t
